# %% [markdown]
# <a href="https://colab.research.google.com/github/OmkarK-7/Atten./blob/main/finetune_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
import json
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments
from torch.utils.data import Dataset

reference_table = pd.read_csv('reference-table.csv')
reference_table_dict = reference_table.to_dict(orient='records')
reference_table_dict
# Out:
# [{'Stored in Table': 'NEW',
#   'Value Name': 'New',
#   'Value Description': 'Order has been placed but not yet processed',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'PND',
#   'Value Name': 'Pending',
#   'Value Description': 'Order is awaiting further action',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'PRC',
#   'Value Name': 'Processing',
#   'Value Description': 'Order is being processed',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'PCK',
#   'Value Name': 'Picked',
#   'Value Description': 'Order items have been picked for shipping',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'PKD',
#   'Value Name': 'Packed',
#   'Value Description': 'Order has been packed',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'SHP',
#   'Value Name': 'Shipped',
#   'Value Description': 'Order has been shipped out from the warehouse',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'OOD',
#   'Value Name': 'Out for Delivery',
#   'Value Description': 'Order is out for delivery to the customer',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'DEL',
#   'Value Name': 'Delivered',
#   'Value Description': 'Order has been delivered to the customer',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'RTN',
#   'Value Name': 'Returned',
#   'Value Description': 'Order has been returned by the customer',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'CAN',
#   'Value Name': 'Cancelled',
#   'Value Description': 'Order has been cancelled',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'REF',
#   'Value Name': 'Refunded',
#   'Value Description': 'Payment has been refunded',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'HOL',
#   'Value Name': 'On Hold',
#   'Value Description': 'Order is on hold, pending review or information',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'FLD',
#   'Value Name': 'Failed',
#   'Value Description': 'Order processing has failed',
#   'Column Name ': 'Order Status'},
#  {'Stored in Table': 'SP',
#   'Value Name': 'Standard Shipping',
#   'Value Description': 'Delivery within standard time frame',
#   'Column Name ': 'Shipping Method'},
#  {'Stored in Table': 'EX',
#   'Value Name': 'Express Shipping',
#   'Value Description': 'Faster delivery for an additional fee',
#   'Column Name ': 'Shipping Method'},
#  {'Stored in Table': 'FS',
#   'Value Name': 'Free Shipping',
#   'Value Description': 'No shipping charge, conditions may apply',
#   'Column Name ': 'Shipping Method'},
#  {'Stored in Table': 'PS',
#   'Value Name': 'Pickup in Store',
#   'Value Description': 'Order can be picked up at a store location',
#   'Column Name ': 'Shipping Method'},
#  {'Stored in Table': 'OD',
#   'Value Name': 'Overnight Delivery',
#   'Value Description': 'Next day delivery',
#   'Column Name ': 'Shipping Method'},
#  {'Stored in Table': 'New York',
#   'Value Name': 'New York',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Los Angeles',
#   'Value Name': 'Los Angeles',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Chicago',
#   'Value Name': 'Chicago',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Houston',
#   'Value Name': 'Houston',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Phoenix',
#   'Value Name': 'Phoenix',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Philadelphia',
#   'Value Name': 'Philadelphia',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'San Antonio',
#   'Value Name': 'San Antonio',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'San Diego',
#   'Value Name': 'San Diego',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Dallas',
#   'Value Name': 'Dallas',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'San Jose',
#   'Value Name': 'San Jose',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Austin',
#   'Value Name': 'Austin',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Jacksonville',
#   'Value Name': 'Jacksonville',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Fort Worth',
#   'Value Name': 'Fort Worth',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Columbus',
#   'Value Name': 'Columbus',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Indianapolis',
#   'Value Name': 'Indianapolis',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Charlotte',
#   'Value Name': 'Charlotte',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'San Francisco',
#   'Value Name': 'San Francisco',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Seattle',
#   'Value Name': 'Seattle',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Denver',
#   'Value Name': 'Denver',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Washington D.C.',
#   'Value Name': 'Washington D.C.',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Nashville',
#   'Value Name': 'Nashville',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Oklahoma City',
#   'Value Name': 'Oklahoma City',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'El Paso',
#   'Value Name': 'El Paso',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Boston',
#   'Value Name': 'Boston',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Portland',
#   'Value Name': 'Portland',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Las Vegas',
#   'Value Name': 'Las Vegas',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Detroit',
#   'Value Name': 'Detroit',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Memphis',
#   'Value Name': 'Memphis',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Louisville',
#   'Value Name': 'Louisville',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Baltimore',
#   'Value Name': 'Baltimore',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Milwaukee',
#   'Value Name': 'Milwaukee',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Albuquerque',
#   'Value Name': 'Albuquerque',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Tucson',
#   'Value Name': 'Tucson',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Fresno',
#   'Value Name': 'Fresno',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Sacramento',
#   'Value Name': 'Sacramento',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Kansas City',
#   'Value Name': 'Kansas City',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Mesa',
#   'Value Name': 'Mesa',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Atlanta',
#   'Value Name': 'Atlanta',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Omaha',
#   'Value Name': 'Omaha',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Colorado Springs',
#   'Value Name': 'Colorado Springs',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Raleigh',
#   'Value Name': 'Raleigh',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Long Beach',
#   'Value Name': 'Long Beach',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Virginia Beach',
#   'Value Name': 'Virginia Beach',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Miami',
#   'Value Name': 'Miami',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Oakland',
#   'Value Name': 'Oakland',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Minneapolis',
#   'Value Name': 'Minneapolis',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Tulsa',
#   'Value Name': 'Tulsa',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Arlington',
#   'Value Name': 'Arlington',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'New Orleans',
#   'Value Name': 'New Orleans',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Wichita',
#   'Value Name': 'Wichita',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Cleveland',
#   'Value Name': 'Cleveland',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Tampa',
#   'Value Name': 'Tampa',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Bakersfield',
#   'Value Name': 'Bakersfield',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Aurora',
#   'Value Name': 'Aurora',
#   'Value Description': 'Major city in the US',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Germany',
#   'Value Name': 'Germany',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'France',
#   'Value Name': 'France',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Italy',
#   'Value Name': 'Italy',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Spain',
#   'Value Name': 'Spain',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'United Kingdom',
#   'Value Name': 'United Kingdom',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Netherlands',
#   'Value Name': 'Netherlands',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Belgium',
#   'Value Name': 'Belgium',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Switzerland',
#   'Value Name': 'Switzerland',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Poland',
#   'Value Name': 'Poland',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Sweden',
#   'Value Name': 'Sweden',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Norway',
#   'Value Name': 'Norway',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Denmark',
#   'Value Name': 'Denmark',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Finland',
#   'Value Name': 'Finland',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Portugal',
#   'Value Name': 'Portugal',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Austria',
#   'Value Name': 'Austria',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Ireland',
#   'Value Name': 'Ireland',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Czech Republic',
#   'Value Name': 'Czech Republic',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Greece',
#   'Value Name': 'Greece',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Hungary',
#   'Value Name': 'Hungary',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Romania',
#   'Value Name': 'Romania',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Bulgaria',
#   'Value Name': 'Bulgaria',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Slovakia',
#   'Value Name': 'Slovakia',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Lithuania',
#   'Value Name': 'Lithuania',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Latvia',
#   'Value Name': 'Latvia',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Estonia',
#   'Value Name': 'Estonia',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Slovenia',
#   'Value Name': 'Slovenia',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Croatia',
#   'Value Name': 'Croatia',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Bosnia and Herzegovina',
#   'Value Name': 'Bosnia and Herzegovina',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Serbia',
#   'Value Name': 'Serbia',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Montenegro',
#   'Value Name': 'Montenegro',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'North Macedonia',
#   'Value Name': 'North Macedonia',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Albania',
#   'Value Name': 'Albania',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Kosovo',
#   'Value Name': 'Kosovo',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Cyprus',
#   'Value Name': 'Cyprus',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Malta',
#   'Value Name': 'Malta',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Luxembourg',
#   'Value Name': 'Luxembourg',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Monaco',
#   'Value Name': 'Monaco',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Liechtenstein',
#   'Value Name': 'Liechtenstein',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Iceland',
#   'Value Name': 'Iceland',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Andorra',
#   'Value Name': 'Andorra',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'San Marino',
#   'Value Name': 'San Marino',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Vatican City',
#   'Value Name': 'Vatican City',
#   'Value Description': 'A major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'London',
#   'Value Name': 'London',
#   'Value Description': 'Major city in the United Kingdom',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Paris',
#   'Value Name': 'Paris',
#   'Value Description': 'Major city in France',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Berlin',
#   'Value Name': 'Berlin',
#   'Value Description': 'Major city in Germany',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Madrid',
#   'Value Name': 'Madrid',
#   'Value Description': 'Major city in Spain',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Rome',
#   'Value Name': 'Rome',
#   'Value Description': 'Major city in Italy',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Amsterdam',
#   'Value Name': 'Amsterdam',
#   'Value Description': 'Major city in the Netherlands',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Prague',
#   'Value Name': 'Prague',
#   'Value Description': 'Major city in Czech Republic',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Vienna',
#   'Value Name': 'Vienna',
#   'Value Description': 'Major city in Austria',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Budapest',
#   'Value Name': 'Budapest',
#   'Value Description': 'Major city in Hungary',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Barcelona',
#   'Value Name': 'Barcelona',
#   'Value Description': 'Major city in Spain',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Munich',
#   'Value Name': 'Munich',
#   'Value Description': 'Major city in Germany',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Lisbon',
#   'Value Name': 'Lisbon',
#   'Value Description': 'Major city in Portugal',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Brussels',
#   'Value Name': 'Brussels',
#   'Value Description': 'Major city in Belgium',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Stockholm',
#   'Value Name': 'Stockholm',
#   'Value Description': 'Major city in Sweden',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Copenhagen',
#   'Value Name': 'Copenhagen',
#   'Value Description': 'Major city in Denmark',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Dublin',
#   'Value Name': 'Dublin',
#   'Value Description': 'Major city in Ireland',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Athens',
#   'Value Name': 'Athens',
#   'Value Description': 'Major city in Greece',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Oslo',
#   'Value Name': 'Oslo',
#   'Value Description': 'Major city in Norway',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Helsinki',
#   'Value Name': 'Helsinki',
#   'Value Description': 'Major city in Finland',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Zurich',
#   'Value Name': 'Zurich',
#   'Value Description': 'Major city in Switzerland',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Warsaw',
#   'Value Name': 'Warsaw',
#   'Value Description': 'Major city in Poland',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Istanbul',
#   'Value Name': 'Istanbul',
#   'Value Description': 'Major city in Turkey',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Moscow',
#   'Value Name': 'Moscow',
#   'Value Description': 'Major city in Russia',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Saint Petersburg',
#   'Value Name': 'Saint Petersburg',
#   'Value Description': 'Major city in Russia',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Milan',
#   'Value Name': 'Milan',
#   'Value Description': 'Major city in Italy',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Edinburgh',
#   'Value Name': 'Edinburgh',
#   'Value Description': 'Major city in the United Kingdom',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Venice',
#   'Value Name': 'Venice',
#   'Value Description': 'Major city in Italy',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Frankfurt',
#   'Value Name': 'Frankfurt',
#   'Value Description': 'Major city in Germany',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Geneva',
#   'Value Name': 'Geneva',
#   'Value Description': 'Major city in Switzerland',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Florence',
#   'Value Name': 'Florence',
#   'Value Description': 'Major city in Italy',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Nice',
#   'Value Name': 'Nice',
#   'Value Description': 'Major city in France',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Lyon',
#   'Value Name': 'Lyon',
#   'Value Description': 'Major city in France',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Krakow',
#   'Value Name': 'Krakow',
#   'Value Description': 'Major city in Poland',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Valencia',
#   'Value Name': 'Valencia',
#   'Value Description': 'Major city in Spain',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Seville',
#   'Value Name': 'Seville',
#   'Value Description': 'Major city in Spain',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Porto',
#   'Value Name': 'Porto',
#   'Value Description': 'Major city in Portugal',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Naples',
#   'Value Name': 'Naples',
#   'Value Description': 'Major city in Italy',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Luxembourg',
#   'Value Name': 'Luxembourg',
#   'Value Description': 'Major city in Luxembourg',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Reykjavik',
#   'Value Name': 'Reykjavik',
#   'Value Description': 'Major city in Iceland',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Sofia',
#   'Value Name': 'Sofia',
#   'Value Description': 'Major city in Bulgaria',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Bucharest',
#   'Value Name': 'Bucharest',
#   'Value Description': 'Major city in Romania',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Belgrade',
#   'Value Name': 'Belgrade',
#   'Value Description': 'Major city in Serbia',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Budapest',
#   'Value Name': 'Budapest',
#   'Value Description': 'Major city in Hungary',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Riga',
#   'Value Name': 'Riga',
#   'Value Description': 'Major city in Latvia',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Tallinn',
#   'Value Name': 'Tallinn',
#   'Value Description': 'Major city in Estonia',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'Vilnius',
#   'Value Name': 'Vilnius',
#   'Value Description': 'Major city in Lithuania',
#   'Column Name ': 'city'},
#  {'Stored in Table': 'USA',
#   'Value Name': 'United States',
#   'Value Description': 'Major country in North America',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Brazil',
#   'Value Name': 'Brazil',
#   'Value Description': 'Major country in South America',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'China',
#   'Value Name': 'China',
#   'Value Description': 'Major country in Asia',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'India',
#   'Value Name': 'India',
#   'Value Description': 'Major country in Asia',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Russia',
#   'Value Name': 'Russia',
#   'Value Description': 'Major country in Europe and Asia',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Germany',
#   'Value Name': 'Germany',
#   'Value Description': 'Major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Australia',
#   'Value Name': 'Australia',
#   'Value Description': 'Major country in Australia/Oceania',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'South Africa',
#   'Value Name': 'South Africa',
#   'Value Description': 'Major country in Africa',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Egypt',
#   'Value Name': 'Egypt',
#   'Value Description': 'Major country in Africa',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Nigeria',
#   'Value Name': 'Nigeria',
#   'Value Description': 'Major country in Africa',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Saudi Arabia',
#   'Value Name': 'Saudi Arabia',
#   'Value Description': 'Major country in Asia',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Japan',
#   'Value Name': 'Japan',
#   'Value Description': 'Major country in Asia',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Mexico',
#   'Value Name': 'Mexico',
#   'Value Description': 'Major country in North America',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Canada',
#   'Value Name': 'Canada',
#   'Value Description': 'Major country in North America',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Argentina',
#   'Value Name': 'Argentina',
#   'Value Description': 'Major country in South America',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Colombia',
#   'Value Name': 'Colombia',
#   'Value Description': 'Major country in South America',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Indonesia',
#   'Value Name': 'Indonesia',
#   'Value Description': 'Major country in Asia',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'France',
#   'Value Name': 'France',
#   'Value Description': 'Major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'United Kingdom',
#   'Value Name': 'United Kingdom',
#   'Value Description': 'Major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'Italy',
#   'Value Name': 'Italy',
#   'Value Description': 'Major country in Europe',
#   'Column Name ': 'country'},
#  {'Stored in Table': 'PM_CC',
#   'Value Name': 'Credit Card',
#   'Value Description': 'Payments made via credit card',
#   'Column Name ': 'payment_type'},
#  {'Stored in Table': 'PM_DC',
#   'Value Name': 'Debit Card',
#   'Value Description': 'Payments made via debit card',
#   'Column Name ': 'payment_type'},
#  {'Stored in Table': 'PM_PP',
#   'Value Name': 'PayPal',
#   'Value Description': 'Payments made via PayPal',
#   'Column Name ': 'payment_type'},
#  {'Stored in Table': 'PM_BNPL',
#   'Value Name': 'Buy Now Pay Later',
#   'Value Description': 'Deferred payment option',
#   'Column Name ': 'payment_type'},
#  {'Stored in Table': 'PM_WT',
#   'Value Name': 'Wire Transfer',
#   'Value Description': 'Payments made via wire transfer',
#   'Column Name ': 'payment_type'},
#  {'Stored in Table': 'PM_COD',
#   'Value Name': 'Cash on Delivery',
#   'Value Description': 'Payment made at the time of delivery',
#   'Column Name ': 'payment_type'},
#  {'Stored in Table': 'SM_STD',
#   'Value Name': 'Standard Shipping',
#   'Value Description': 'Delivery within standard time frame',
#   'Column Name ': 'shipping_type'},
#  {'Stored in Table': 'SM_EXP',
#   'Value Name': 'Express Shipping',
#   'Value Description': 'Faster delivery for an additional fee',
#   'Column Name ': 'shipping_type'},
#  {'Stored in Table': 'SM_FRS',
#   'Value Name': 'Free Shipping',
#   'Value Description': 'No shipping charge, conditions may apply',
#   'Column Name ': 'shipping_type'},
#  {'Stored in Table': 'SM_INT',
#   'Value Name': 'International Shipping',
#   'Value Description': 'Delivery to international destinations',
#   'Column Name ': 'shipping_type'},
#  {'Stored in Table': 'SM_LCL',
#   'Value Name': 'Local Pickup',
#   'Value Description': 'Pickup from a local store or depot',
#   'Column Name ': 'shipping_type'},
#  {'Stored in Table': 'SM_DRS',
#   'Value Name': 'Drone Shipping',
#   'Value Description': 'Delivery via drone, where available',
#   'Column Name ': 'shipping_type'},
#  {'Stored in Table': 'XS',
#   'Value Name': 'Extra Small',
#   'Value Description': 'Smallest standard size',
#   'Column Name ': 'size'},
#  {'Stored in Table': 'S',
#   'Value Name': 'Small',
#   'Value Description': 'Small size',
#   'Column Name ': 'size'},
#  {'Stored in Table': 'M',
#   'Value Name': 'Medium',
#   'Value Description': 'Medium size, often standard',
#   'Column Name ': 'size'},
#  {'Stored in Table': 'L',
#   'Value Name': 'Large',
#   'Value Description': 'Large size',
#   'Column Name ': 'size'},
#  {'Stored in Table': 'XL',
#   'Value Name': 'Extra Large',
#   'Value Description': 'Larger than standard size',
#   'Column Name ': 'size'},
#  {'Stored in Table': 'XXL',
#   'Value Name': 'Double XL',
#   'Value Description': 'Very large size',
#   'Column Name ': 'size'},
#  {'Stored in Table': 'XXXL',
#   'Value Name': 'Triple XL',
#   'Value Description': 'Extraordinarily large size',
#   'Column Name ': 'size'},
#  {'Stored in Table': 'Red',
#   'Value Name': 'Red',
#   'Value Description': 'A vibrant primary color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Blue',
#   'Value Name': 'Blue',
#   'Value Description': 'A calming primary color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Green',
#   'Value Name': 'Green',
#   'Value Description': 'A refreshing primary color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Black',
#   'Value Name': 'Black',
#   'Value Description': 'A classic and versatile color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'White',
#   'Value Name': 'White',
#   'Value Description': 'A pure and simple color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Yellow',
#   'Value Name': 'Yellow',
#   'Value Description': 'A bright and cheerful color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Purple',
#   'Value Name': 'Purple',
#   'Value Description': 'A regal and mysterious color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Orange',
#   'Value Name': 'Orange',
#   'Value Description': 'A bold and energetic color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Grey',
#   'Value Name': 'Grey',
#   'Value Description': 'A neutral and flexible color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Brown',
#   'Value Name': 'Brown',
#   'Value Description': 'A warm and natural color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Pink',
#   'Value Name': 'Pink',
#   'Value Description': 'A playful and romantic color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Navy',
#   'Value Name': 'Navy',
#   'Value Description': 'A deep and professional color',
#   'Column Name ': 'color'},
#  {'Stored in Table': 'Mon',
#   'Value Name': 'Monday',
#   'Value Description': 'First day of the work week',
#   'Column Name ': 'day_of_week'},
#  {'Stored in Table': 'Tue',
#   'Value Name': 'Tuesday',
#   'Value Description': 'Second day of the work week',
#   'Column Name ': 'day_of_week'},
#  {'Stored in Table': 'Wed',
#   'Value Name': 'Wednesday',
#   'Value Description': 'Midweek day',
#   'Column Name ': 'day_of_week'},
#  {'Stored in Table': 'Thu',
#   'Value Name': 'Thursday',
#   'Value Description': 'Fourth day of the work week',
#   'Column Name ': 'day_of_week'},
#  {'Stored in Table': 'Fri',
#   'Value Name': 'Friday',
#   'Value Description': 'Last day of the work week',
#   'Column Name ': 'day_of_week'},
#  {'Stored in Table': 'Sat',
#   'Value Name': 'Saturday',
#   'Value Description': 'First day of the weekend',
#   'Column Name ': 'day_of_week'},
#  {'Stored in Table': 'Sun',
#   'Value Name': 'Sunday',
#   'Value Description': 'Second day of the weekend',
#   'Column Name ': 'day_of_week'},
#  {'Stored in Table': 'New Years Day',
#   'Value Name': "New Year's Day",
#   'Value Description': 'Celebrates the first day of the new year (January 1)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'MLK Day',
#   'Value Name': 'Martin Luther King Jr. Day',
#   'Value Description': 'Honors civil rights leader Martin Luther King Jr. (Third Monday in January)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Presidents Day',
#   'Value Name': "Presidents' Day",
#   'Value Description': 'Honors all U.S. presidents (Third Monday in February)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Memorial Day',
#   'Value Name': 'Memorial Day',
#   'Value Description': 'Honors military personnel who died in service (Last Monday in May)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Independence Day',
#   'Value Name': 'Independence Day',
#   'Value Description': 'Celebrates the declaration of independence (July 4)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Labor Day',
#   'Value Name': 'Labor Day',
#   'Value Description': 'Honors the labor movement (First Monday in September)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Columbus Day',
#   'Value Name': 'Columbus Day',
#   'Value Description': "Commemorates Christopher Columbus' landing (Second Monday in October)",
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Veterans Day',
#   'Value Name': 'Veterans Day',
#   'Value Description': 'Honors military veterans (November 11)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Thanksgiving',
#   'Value Name': 'Thanksgiving',
#   'Value Description': 'Celebrates giving thanks and harvest (Fourth Thursday in November)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Black Friday',
#   'Value Name': 'Black Friday',
#   'Value Description': 'Major retail sales day following Thanksgiving (Friday after Thanksgiving)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Cyber Monday',
#   'Value Name': 'Cyber Monday',
#   'Value Description': 'Online shopping deals following Thanksgiving weekend (Monday after Thanksgiving)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Christmas Day',
#   'Value Name': 'Christmas Day',
#   'Value Description': 'Celebrates the birth of Jesus Christ (December 25)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Halloween',
#   'Value Name': 'Halloween',
#   'Value Description': 'Celebration involving costumes and candies (October 31)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Valentines Day',
#   'Value Name': "Valentine's Day",
#   'Value Description': 'Celebration of romance and love (February 14)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Easter',
#   'Value Name': 'Easter',
#   'Value Description': 'Celebrates the Christian belief in the resurrection of Jesus Christ (Date varies, first Sunday after the first full moon following the March equinox)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'St Patricks Day',
#   'Value Name': "St. Patrick's Day",
#   'Value Description': 'Celebrates Irish culture and the patron saint of Ireland (March 17)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Earth Day',
#   'Value Name': 'Earth Day',
#   'Value Description': 'Promotes environmental protection (April 22)',
#   'Column Name ': 'holiday'},
#  {'Stored in Table': 'Active',
#   'Value Name': 'Active',
#   'Value Description': 'Customer actively engaging and making purchases',
#   'Column Name ': 'status'},
#  {'Stored in Table': 'Inactive',
#   'Value Name': 'Inactive',
#   'Value Description': 'Customer has not engaged or made purchases recently',
#   'Column Name ': 'status'},
#  {'Stored in Table': 'Prospect',
#   'Value Name': 'Prospect',
#   'Value Description': 'Potential customer not yet making purchases',
#   'Column Name ': 'status'},
#  {'Stored in Table': 'Churned',
#   'Value Name': 'Churned',
#   'Value Description': 'Customer who has stopped using services',
#   'Column Name ': 'status'},
#  {'Stored in Table': 'Loyalty Member',
#   'Value Name': 'Loyalty Member',
#   'Value Description': 'Customer who is part of the loyalty program',
#   'Column Name ': 'status'},
#  {'Stored in Table': 'VIP',
#   'Value Name': 'VIP',
#   'Value Description': 'High-value customer with benefits and rewards',
#   'Column Name ': 'status'},
#  {'Stored in Table': 'At Risk',
#   'Value Name': 'At Risk',
#   'Value Description': 'Customer at risk of becoming inactive or churning',
#   'Column Name ': 'status'},
#  {'Stored in Table': 'New',
#   'Value Name': 'New',
#   'Value Description': 'Newly acquired customer',
#   'Column Name ': 'status'},
#  {'Stored in Table': 'Returning',
#   'Value Name': 'Returning',
#   'Value Description': 'Customer who has resumed activity after a period of inactivity',
#   'Column Name ': 'status'},
#  {'Stored in Table': 'M',
#   'Value Name': 'Male',
#   'Value Description': 'Identifies a male individual',
#   'Column Name ': 'gender'},
#  {'Stored in Table': 'F',
#   'Value Name': 'Female',
#   'Value Description': 'Identifies a female individual',
#   'Column Name ': 'gender'},
#  {'Stored in Table': 'NB',
#   'Value Name': 'Non-Binary',
#   'Value Description': 'Identifies a non-binary individual',
#   'Column Name ': 'gender'},
#  {'Stored in Table': 'PNTS',
#   'Value Name': 'Prefer Not to Say',
#   'Value Description': 'Customer prefers not to specify gender',
#   'Column Name ': 'gender'},
#  {'Stored in Table': 'O',
#   'Value Name': 'Other',
#   'Value Description': 'Any other gender not listed above',
#   'Column Name ': 'gender'},
#  {'Stored in Table': 'Gold',
#   'Value Name': 'Gold',
#   'Value Description': 'Highest tier in the loyalty program',
#   'Column Name ': 'program_type'},
#  {'Stored in Table': 'Silver',
#   'Value Name': 'Silver',
#   'Value Description': 'Middle tier in the loyalty program',
#   'Column Name ': 'program_type'},
#  {'Stored in Table': 'Bronze',
#   'Value Name': 'Bronze',
#   'Value Description': 'Entry-level tier in the loyalty program',
#   'Column Name ': 'program_type'},
#  {'Stored in Table': 'Platinum',
#   'Value Name': 'Platinum',
#   'Value Description': 'Exclusive tier above Gold, often by invite',
#   'Column Name ': 'program_type'},
#  {'Stored in Table': 'Basic',
#   'Value Name': 'Basic',
#   'Value Description': 'Basic access with minimal benefits',
#   'Column Name ': 'program_type'},
#  {'Stored in Table': 'Active',
#   'Value Name': 'Active',
#   'Value Description': 'Membership is currently active and in good standing',
#   'Column Name ': 'membership_status'},
#  {'Stored in Table': 'Inactive',
#   'Value Name': 'Inactive',
#   'Value Description': 'Membership is currently inactive, no ongoing transactions',
#   'Column Name ': 'membership_status'},
#  {'Stored in Table': 'Suspended',
#   'Value Name': 'Suspended',
#   'Value Description': 'Membership is temporarily suspended due to various reasons',
#   'Column Name ': 'membership_status'},
#  {'Stored in Table': 'Cancelled',
#   'Value Name': 'Cancelled',
#   'Value Description': 'Membership has been cancelled by the user or the provider',
#   'Column Name ': 'membership_status'},
#  {'Stored in Table': 'Expired',
#   'Value Name': 'Expired',
#   'Value Description': 'Membership has expired and has not been renewed',
#   'Column Name ': 'membership_status'},
#  {'Stored in Table': 'Pending',
#   'Value Name': 'Pending',
#   'Value Description': 'Membership application is under review or awaiting further action',
#   'Column Name ': 'membership_status'},
#  {'Stored in Table': 'High Value',
#   'Value Name': 'High Value',
#   'Value Description': 'Customers with high purchase frequency and high spending',
#   'Column Name ': 'customer_segment'},
#  {'Stored in Table': 'Mid Value',
#   'Value Name': 'Mid Value',
#   'Value Description': 'Customers with moderate purchase frequency and spending',
#   'Column Name ': 'customer_segment'},
#  {'Stored in Table': 'Low Value',
#   'Value Name': 'Low Value',
#   'Value Description': 'Customers with low purchase frequency and spending',
#   'Column Name ': 'customer_segment'},
#  {'Stored in Table': 'Premium',
#   'Value Name': 'Premium',
#   'Value Description': 'Customers who consistently make large purchases',
#   'Column Name ': 'customer_segment'},
#  {'Stored in Table': 'Loyal',
#   'Value Name': 'Loyal',
#   'Value Description': 'Customers who have been with the business for a long time',
#   'Column Name ': 'customer_segment'},
#  {'Stored in Table': 'New',
#   'Value Name': 'New',
#   'Value Description': 'Recently acquired customers',
#   'Column Name ': 'customer_segment'},
#  {'Stored in Table': 'At Risk',
#   'Value Name': 'At Risk',
#   'Value Description': 'Customers who may churn due to low engagement or satisfaction',
#   'Column Name ': 'customer_segment'},
#  {'Stored in Table': 'Discount Seeker',
#   'Value Name': 'Discount Seeker',
#   'Value Description': 'Customers primarily motivated by promotions and discounts',
#   'Column Name ': 'customer_segment'},
#  {'Stored in Table': 'VIP',
#   'Value Name': 'VIP',
#   'Value Description': 'Customers recognized for exceptional loyalty and spending, often receiving exclusive perks',
#   'Column Name ': 'customer_segment'}]

# %%
import os
import json

data_model = {}

# Path to the data model directory
data_model_dir = 'https://github.com/OmkarK-7/Atten./tree/8722a35c6f03b603da3a9282ea6ba47623df0ac8/DataModel/ecom_tables_and_columns_new_with_dimensions'

# Traverse through the subfolders and read JSON files
for subdir, _, files in os.walk(data_model_dir):
    for file in files:
        if file.endswith('.json'):
            file_path = os.path.join(subdir, file)
            with open(file_path, 'r') as f:
                table_data = json.load(f)
                table_name = table_data['table_name']
                data_model[table_name] = table_data

print(json.dumps(data_model, indent=4))  # Print to verify the loaded data
# Out:
# {}

# %%
# Loading pre-trained model( using gpt-2 for this case) and tokenizer.
model_name = 'gpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Create training data this will take a lot of time and not fully complete.
train_data = [
    {"input": "What is the average duration from order placement to shipment across different product categories, segmented by customer regions and order volume?",
     "output": {
         "tables": ["order", "product", "customer"],
         "columns": ["order.order_date", "order.shipped_date", "product.category", "customer.region", "order.order_volume"],
         "relationships": [{"from_table": "order", "from_column": "product_id", "to_table": "product", "to_column": "product_id"},
                           {"from_table": "order", "from_column": "customer_id", "to_table": "customer", "to_column": "customer_id"}]
     },
     "input": "How can I determine the peak shopping hours by analyzing the times at which customers complete their purchases on our e-commerce platform?",
     "output": {
         "tables": ["order", "product", "customer"],
         "columns": ["order.order_date", "order.shipped_date", "product.category", "customer.region", "order.order_volume"],
         "relationships": [{"from_table": "order", "from_column": "product_id", "to_table": "product", "to_column": "product_id"},
                           {"from_table": "order", "from_column": "customer_id", "to_table": "customer", "to_column": "customer_id"}]
     }

     },
    # Have to add more question-answer pairs
]

# Tokenize and prepare data for training
def preprocess_data(data):
    inputs = tokenizer([item['input'] for item in data], return_tensors='pt', truncation=True, padding=True, max_length=512)
    outputs = tokenizer([str(item['output']) for item in data], return_tensors='pt', truncation=True, padding=True, max_length=512)
    return inputs, outputs

inputs, outputs = preprocess_data(train_data)

# Training arguments
training_args = TrainingArguments(output_dir='./results',
                                  num_train_epochs=3,
                                  per_device_train_batch_size=4,
                                  save_steps=10_000,
                                  save_total_limit=2,
                                  )

trainer = Trainer(model=model, args=training_args, train_dataset=inputs, eval_dataset=outputs,)
trainer.train()

# %% [markdown]
# **Creating the Validation Dataset**
#
# You can create a validation dataset from the provided questions or use some other questions if available. The process involves selecting a subset of the questions, manually mapping them to the relevant columns and tables, and then using this subset for validation.

# %%
# Load the Questions
questions_df = pd.read_csv('questions.csv')

# Select a Subset for Validation
# Assuming the 'questions.csv' has a column named 'Question'
validation_subset = questions_df.sample(n=10)  # Select 10 random questions for validation

# Step 3: Manually Map Selected Questions
# For demonstration purposes, we are creating dummy mappings. In practice, this should be done manually.
manual_mappings = {
    "What is the average duration from order placement to shipment across different product categories, segmented by customer regions and order volume?": {
        "tables": ["order", "product", "customer"],
        "columns": ["order.order_date", "order.shipped_date", "product.category", "customer.region", "order.order_volume"],
        "relationships": [
            {"from_table": "order", "from_column": "product_id", "to_table": "product", "to_column": "product_id"},
            {"from_table": "order", "from_column": "customer_id", "to_table": "customer", "to_column": "customer_id"}
        ]
    },
    "How can I determine the peak shopping hours by analyzing the times at which customers complete their purchases on our e-commerce platform?": {
        "tables": ["order", "customer"],
        "columns": ["order.order_time", "customer.customer_id"],
        "relationships": [
            {"from_table": "order", "from_column": "customer_id", "to_table": "customer", "to_column": "customer_id"}
        ]
    },
    # Have to add more mappings for the selected questions
}

# Prepare the Validation Dataset
validation_data = []
for question in validation_subset['Question']:
    if question in manual_mappings:
        validation_data.append({
            "question": question,
            "mapping": manual_mappings[question]
        })

# Save the Validation Dataset
with open('validation_dataset.json', 'w') as f:
    json.dump(validation_data, f, indent=4)

print("Validation dataset created and saved as 'validation_dataset.json'")

# %%
# Load the validation dataset
with open('validation_dataset.json', 'r') as f:
    validation_data = json.load(f)

# %%
# Load pre-trained model and tokenizer
model_name = 'gpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Prepare validation data
def preprocess_data(data):
    inputs = [item['question'] for item in data]
    outputs = [json.dumps(item['mapping']) for item in data]

    input_encodings = tokenizer(inputs, truncation=True, padding=True, max_length=512, return_tensors='pt')
    output_encodings = tokenizer(outputs, truncation=True, padding=True, max_length=512, return_tensors='pt')

    return input_encodings, output_encodings

validation_inputs, validation_outputs = preprocess_data(validation_data)

# %%
class ValidationDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels['input_ids'][idx])
        return item

    def __len__(self):
        return len(self.encodings.input_ids)

# Create validation dataset
val_dataset = ValidationDataset(validation_inputs, validation_outputs)

# Training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    save_steps=10_000,
    save_total_limit=2,
    evaluation_strategy="epoch"
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    eval_dataset=val_dataset,
)

# Evaluate the model
eval_results = trainer.evaluate()

print("Evaluation results:", eval_results)

# %% [markdown]
# # Using the Finetuned Model
#
# After fine-tuning the model and validated its performance, we should set up a pipeline to interact with the model and ask questions.

# %%
# Load the fine-tuned model and tokenizer
model_path = './results/checkpoint-last'  # Model's save path
tokenizer = GPT2Tokenizer.from_pretrained(model_path)
model = GPT2LMHeadModel.from_pretrained(model_path)

# %%
def ask_question(question):
    # Tokenize the input question
    inputs = tokenizer(question, return_tensors='pt', truncation=True, padding=True, max_length=512)

    # Generate the model's output
    with torch.no_grad():
        outputs = model.generate(inputs['input_ids'], max_length=512, num_return_sequences=1)

    # Decode the output
    output_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return output_text

# %%
def parse_output(output_text):
    try:
        output_data = json.loads(output_text)
        return output_data
    except json.JSONDecodeError:
        return {"error": "Failed to parse model output."}

# Example usage
question = "Give me top 5 customers with most number of orders."
raw_output = ask_question(question)
parsed_output = parse_output(raw_output)

print(json.dumps(parsed_output, indent=4))
